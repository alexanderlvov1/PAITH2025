# %% [markdown]
# # Matplotlib
# Read the links https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before starting the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
#1) Object-Oriented (OO) approach - Creating explicit Figure and Axes objects
#2) Pyplot (state-based) approach - Using plt.plot(), plt.title(), etc. directly
# The OO is the reomemmended but both are accaptable.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
# Figure is the whole window or page that contains everything. 
# Axes is a single plot area withing a figure where data is plotted. It has x and y axes. One figure can contain multiple axes or subplots.
# Axis is the invidual lines (x-axis or y-axis) that the define the scale and liits the of the plot. Each Axes typically has two axis (x and y).
# Artist is everything one can see on a figure. This includes the figure itself, area, axis, lines, text, labels etc.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
#The expected input data type for Matplotlib is array-like objects, which includes:

#NumPy arrays (most common and recommended)
#Python lists
#Tuples
#Pandas Series/DataFrames

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4, 4, 100)
y = x**2

# Object-Oriented approach
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("Function y = x^2")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# Pyplot approach
plt.figure()
plt.plot(x, y)
plt.title("Function y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
fix, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# First subplot - Scatter plot
ax1.scatter(random_data_x, random_data_y, alpha=0.5)
ax1.set_title("Scatter Plot of Random Data")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")   

# Second subplot - Bar plot
ax2.bar(names, values)
ax2.set_title("Bar Plot of Fruit Data")
ax2.set_xlabel("Fruit")
ax2.set_ylabel("Count")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
